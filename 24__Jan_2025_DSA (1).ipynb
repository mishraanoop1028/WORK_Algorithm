# %% [markdown]
# #DSA
# ▶

# %% [markdown]
# ## 1_Array

# %%
import array as arr
myArray = arr.array('d' , [3.14,3.5,4.99])
print(myArray)
myArray2 = arr.array('i', [1,2,3,5,7,11,13,17,19])
print(myArray2[:-1])
# Out:
# array('d', [3.14, 3.5, 4.99])
# array('i', [1, 2, 3, 5, 7, 11, 13, 17])

# %%
myArray2 = arr.array('i', [1,2,3,5,7,11,13,17,19])
print(myArray2[6:])
# Out:
# array('i', [13, 17, 19])

# %%
myArray2[0]=99
print(myArray2)
# Out:
# array('i', [99, 2, 3, 5, 7, 11, 13, 17, 19])

# %%
myArray2[2:3] = arr.array('i', [88,77])
print(myArray2)
# Out:
# array('i', [99, 2, 88, 77, 5, 7, 11, 13, 17, 19])

# %% [markdown]
# ## 2_Linked_list

# %%
class Node:
  def __init__(mySelf,data):
    mySelf.item = data
    mySelf.ref = None

# %%
class myLinkedList :
  def __init__(mySelf):
    mySelf.start_node = None

# %%
def traverse_list(mySelf):
 if mySelf.start_node is none:
     print("list has no element")
     return
 else:
    n = mySelf.start_node
    while n is not None:
      print(n.item," ")
      n = n.ref

# %% [markdown]
# ## Manupulating the list

# %%
def insert_start(mySelf,data):
  list
  new_node = Node(data)
  new_node.ref =  mySelf.start_node
  mySelf.start_node= new_node

def insert_end(mySelf, data):
  new_node = Node(data)
  if mySelf.start_node is None:
     mySelf.start_node = new_node
  return
  n = mySelf.start_node
  while n.ref is not None:
    n=n.ref
  n.ref = new_node

# %%
def insert_specific(mySelf,x,data):
  n = mySelf.start_node
  print(n.ref)
  while n is not None:
    if n.item == x:
      break
      n = n.ref
      if n is None:
        print("item not in the list")
      else:
          new_node = Node(data)
          new_node.ref = n.ref
          n.ref = new_node

          def insert_index (mySelf,index,data):
            if index == 1:
              new_node =Node(data)
              new_node.ref = mySelf.start_node
              while i < index-1 and n is not None :
                        n = n.ref
                        i =i+1
                        if n is None:
                           print("index iout of bound")
                        else:
                            new_node=Node(data)
                            n.ref = new_node
                            myLIST = myLinkedList()
                            myLIST=[1,2,3]
                            myLIST.insert_end(1)
                            myLIST.insert_end(3)
                            myLIST.insert_end(5)
                            myLIST.traverse_list()
                            myLIST.get_count()

                            myLIST.insert_start(7)
                            myLIST.insert_start(9)
                            myLIST.insert_start(11)

# %%
import pandas as pd

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows to understand the structure
print(df.head())
# Out:
#   customer_id  customer_tenure customer_location customer_type   order_id  \
# 0   CUST00001               39             Delhi     Returning  ORD000001
# 1   CUST00002               52         Hyderabad     Returning  ORD000002
# 2   CUST00003               29              Pune     Returning  ORD000003
# 3   CUST00004               15            Jaipur     Returning  ORD000004
# 4   CUST00005               43              Pune     Returning  ORD000005
#
#   order_date  order_value payment_method  order_frequency  discount_applied  \
# 0    04:51.9      4015.21    Net Banking                9                 5
# 1    39:38.4      2205.61    Credit Card                3                15
# 2    15:18.9       858.84    Net Banking                8                30
# 3    52:58.4       500.00            UPI                1                 0
# 4    17:39.5      1843.50         Wallet                9                40
#
# ...

# %%
# Calculate order frequency per customer
order_frequency = df.groupby('Customer ID')['Purchase Date'].count().reset_index()
order_frequency.columns = ['Customer ID', 'Order Frequency']

# Calculate total revenue per customer (Customer Lifetime Value)
customer_lifetime_value = df.groupby('Customer ID')['Revenue'].sum().reset_index()
customer_lifetime_value.columns = ['Customer ID', 'Lifetime Value']

# Merge the two metrics
customer_behavior = pd.merge(order_frequency, customer_lifetime_value, on='Customer ID')

# Display the results
print(customer_behavior.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-7f445a578498> in <cell line: 0>()
#       1 # Calculate order frequency per customer
# ----> 2 order_frequency = df.groupby('Customer ID')['Purchase Date'].count().reset_index()
#       3 order_frequency.columns = ['Customer ID', 'Order Frequency']
#       4
#       5 # Calculate total revenue per customer (Customer Lifetime Value)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ...

# %%
print(df.columns)
# Out:
# Index(['customer_id', 'customer_tenure', 'customer_location', 'customer_type',
#        'order_id', 'order_date', 'order_value', 'payment_method',
#        'order_frequency', 'discount_applied', 'return_status',
#        'product_category', 'product_sku', 'size', 'inventory_status', 'source',
#        'engagement_score'],
#       dtype='object')

# %%
order_frequency = df.groupby('customer_id')['Purchase Date'].count().reset_index()
order_frequency.columns = ['customer_id', 'Order Frequency']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-2647ab3fc6b4> in <cell line: 0>()
# ----> 1 order_frequency = df.groupby('customer_id')['Purchase Date'].count().reset_index()
#       2 order_frequency.columns = ['customer_id', 'Order Frequency']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
# ...

# %%
# Print column names to verify
print("Columns in the DataFrame:", df.columns.tolist())

# Check if 'Customer ID' exists (case-sensitive)
if 'Customer ID' not in df.columns:
    print("'Customer ID' column not found. Please check the column names.")

    # Look for similar columns (case-insensitive)
    customer_id_col = None
    for col in df.columns:
        if 'customer' in col.lower() and 'id' in col.lower():
            customer_id_col = col
            break

    if customer_id_col:
        print(f"Using column '{customer_id_col}' as 'Customer ID'.")
        order_frequency = df.groupby(customer_id_col)['Purchase Date'].count().reset_index()
        order_frequency.columns = [customer_id_col, 'Order Frequency']
    else:
        print("No suitable column found for customer IDs.")
else:
    # Proceed with the original code
    order_frequency = df.groupby('Customer ID')['Purchase Date'].count().reset_index()
    order_frequency.columns = ['Customer ID', 'Order Frequency']
# Out:
# Columns in the DataFrame: ['customer_id', 'customer_tenure', 'customer_location', 'customer_type', 'order_id', 'order_date', 'order_value', 'payment_method', 'order_frequency', 'discount_applied', 'return_status', 'product_category', 'product_sku', 'size', 'inventory_status', 'source', 'engagement_score']
# 'Customer ID' column not found. Please check the column names.
# Using column 'customer_id' as 'Customer ID'.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-1d9b9e589031> in <cell line: 0>()
#      15     if customer_id_col:
#      16         print(f"Using column '{customer_id_col}' as 'Customer ID'.")
# ---> 17         order_frequency = df.groupby(customer_id_col)['Purchase Date'].count().reset_index()
#      18         order_frequency.columns = [customer_id_col, 'Order Frequency']
#      19     else:
#
# ...

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Purchase Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-dc5c0f03ebbf> in <cell line: 0>()
# ----> 1 df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
#
# ...

# %%
import pandas as pd

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows to understand the structure
print(df.head())
# Out:
#   customer_id  customer_tenure customer_location customer_type   order_id  \
# 0   CUST00001               39             Delhi     Returning  ORD000001
# 1   CUST00002               52         Hyderabad     Returning  ORD000002
# 2   CUST00003               29              Pune     Returning  ORD000003
# 3   CUST00004               15            Jaipur     Returning  ORD000004
# 4   CUST00005               43              Pune     Returning  ORD000005
#
#   order_date  order_value payment_method  order_frequency  discount_applied  \
# 0    04:51.9      4015.21    Net Banking                9                 5
# 1    39:38.4      2205.61    Credit Card                3                15
# 2    15:18.9       858.84    Net Banking                8                30
# 3    52:58.4       500.00            UPI                1                 0
# 4    17:39.5      1843.50         Wallet                9                40
#
# ...

# %%
import pandas as pd

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows to understand the structure
print(df.head())
# Out:
#   customer_id  customer_tenure customer_location customer_type   order_id  \
# 0   CUST00001               39             Delhi     Returning  ORD000001
# 1   CUST00002               52         Hyderabad     Returning  ORD000002
# 2   CUST00003               29              Pune     Returning  ORD000003
# 3   CUST00004               15            Jaipur     Returning  ORD000004
# 4   CUST00005               43              Pune     Returning  ORD000005
#
#   order_date  order_value payment_method  order_frequency  discount_applied  \
# 0    04:51.9      4015.21    Net Banking                9                 5
# 1    39:38.4      2205.61    Credit Card                3                15
# 2    15:18.9       858.84    Net Banking                8                30
# 3    52:58.4       500.00            UPI                1                 0
# 4    17:39.5      1843.50         Wallet                9                40
#
# ...

# %%
# Calculate order frequency per customer
order_frequency = df.groupby('customer_id')['order_id'].count().reset_index()
order_frequency.columns = ['customer_id', 'order_frequency']

# Calculate total revenue per customer (Customer Lifetime Value)
customer_lifetime_value = df.groupby('customer_id')['order_value'].sum().reset_index()
customer_lifetime_value.columns = ['customer_id', 'lifetime_value']

# Merge the two metrics
customer_behavior = pd.merge(order_frequency, customer_lifetime_value, on='customer_id')

# Display the results
print("Customer Behavior Analysis:")
print(customer_behavior.head())
# Out:
# Customer Behavior Analysis:
#   customer_id  order_frequency  lifetime_value
# 0   CUST00001                1         4015.21
# 1   CUST00002                1         2205.61
# 2   CUST00003                1          858.84
# 3   CUST00004                1          500.00
# 4   CUST00005                1         1843.50

# %%
# Top-performing products by revenue
top_products = df.groupby('product_sku')['order_value'].sum().sort_values(ascending=False).reset_index()
print("Top Performing Products:")
print(top_products.head())

# Seasonal trends (monthly revenue)
df['order_date'] = pd.to_datetime(df['order_date'])
df['month'] = df['order_date'].dt.month
monthly_revenue = df.groupby('month')['order_value'].sum().reset_index()
print("Monthly Revenue Trends:")
print(monthly_revenue)

# Revenue drivers (e.g., by product category)
revenue_by_category = df.groupby('product_category')['order_value'].sum().sort_values(ascending=False).reset_index()
print("Revenue by Product Category:")
print(revenue_by_category)
# Out:
# Top Performing Products:
#   product_sku  order_value
# 0     SKU0044      7251.06
# 1     SKU0213      7157.30
# 2     SKU0538      6549.57
# 3     SKU0007      6396.56
# 4     SKU0215      6390.36
# <ipython-input-44-8206a5355bc2>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# <ipython-input-44-8206a5355bc2> in <cell line: 0>()
#       5
#       6 # Seasonal trends (monthly revenue)
# ...

# %%
# Calculate total conversions per marketing channel
conversions_by_source = df.groupby('source')['order_id'].count().reset_index()
conversions_by_source.columns = ['source', 'conversions']

# Calculate total revenue per marketing channel
revenue_by_source = df.groupby('source')['order_value'].sum().reset_index()
revenue_by_source.columns = ['source', 'total_revenue']

# Merge conversions and revenue
marketing_effectiveness = pd.merge(conversions_by_source, revenue_by_source, on='source')

# Display the results
print("Marketing Effectiveness:")
print(marketing_effectiveness)
# Out:
# Marketing Effectiveness:
#             source  conversions  total_revenue
# 0  Email Marketing          219      556655.12
# 1     Facebook Ads          219      554021.25
# 2       Google Ads          185      472040.17
# 3        Instagram          187      485037.28
# 4    Word of Mouth          190      532801.24

# %%
# Calculate return rates by product category and discount
return_rates = df.groupby(['product_category', 'discount_applied'])['return_status'].mean().reset_index()
return_rates.columns = ['product_category', 'discount_applied', 'return_rate']

# Display the results
print("Return Rates by Product Category and Discount:")
print(return_rates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
# Calculate total quantity sold per product (assuming 'order_value' represents quantity)
product_sales = df.groupby('product_sku')['order_value'].sum().reset_index()
product_sales.columns = ['product_sku', 'total_quantity_sold']

# Identify products with low stock (assuming 'inventory_status' indicates stock levels)
if 'inventory_status' in df.columns:
    # Convert 'inventory_status' to a numeric value (e.g., 'In Stock' = 1, 'Out of Stock' = 0)
    df['inventory_status_numeric'] = df['inventory_status'].apply(lambda x: 1 if x == 'In Stock' else 0)

    # Calculate average inventory status per product
    product_stock = df.groupby('product_sku')['inventory_status_numeric'].mean().reset_index()
    product_stock.columns = ['product_sku', 'average_stock_status']

    # Merge sales and stock data
    inventory_risk = pd.merge(product_sales, product_stock, on='product_sku')
    inventory_risk['stockout_risk'] = inventory_risk['total_quantity_sold'] / (inventory_risk['average_stock_status'] + 1e-6)  # Avoid division by zero
    print("Products with High Stockout Risk:")
    print(inventory_risk.sort_values(by='stockout_risk', ascending=False).head())
else:
    print("No 'inventory_status' column found in the dataset.")

# Predictive model for inventory optimization (simplified example)
from sklearn.linear_model import LinearRegression

# Prepare data for prediction
inventory_data = df.groupby('product_sku').agg({'order_value': 'sum', 'inventory_status_numeric': 'mean'}).reset_index()
inventory_data.columns = ['product_sku', 'total_quantity_sold', 'average_stock_status']

# Fit a linear regression model
X = inventory_data[['total_quantity_sold']]
y = inventory_data['average_stock_status']
model = LinearRegression()
model.fit(X, y)

# Predict optimal stock levels
inventory_data['predicted_stock'] = model.predict(X)
print("Predicted Optimal Stock Levels:")
print(inventory_data[['product_sku', 'total_quantity_sold', 'average_stock_status', 'predicted_stock']])
# Out:
# Products with High Stockout Risk:
#     product_sku  total_quantity_sold  average_stock_status  stockout_risk
# 44      SKU0045              5853.51                   0.0   5.853510e+09
# 179     SKU0180              5464.82                   0.0   5.464820e+09
# 12      SKU0013              5106.59                   0.0   5.106590e+09
# 421     SKU0422              5073.55                   0.0   5.073550e+09
# 432     SKU0433              5034.46                   0.0   5.034460e+09
# Predicted Optimal Stock Levels:
#     product_sku  total_quantity_sold  average_stock_status  predicted_stock
# 0       SKU0001              4015.21                   1.0         0.911333
# 1       SKU0002              2205.61                   0.0         0.895557
# 2       SKU0003               858.84                   1.0         0.883816
# 3       SKU0004               500.00                   1.0         0.880688
# 4       SKU0005              1843.50                   1.0         0.892400
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Display the first few rows to understand the structure
print(df.head())
# Out:
#   customer_id  customer_tenure customer_location customer_type   order_id  \
# 0   CUST00001               39             Delhi     Returning  ORD000001
# 1   CUST00002               52         Hyderabad     Returning  ORD000002
# 2   CUST00003               29              Pune     Returning  ORD000003
# 3   CUST00004               15            Jaipur     Returning  ORD000004
# 4   CUST00005               43              Pune     Returning  ORD000005
#
#   order_date  order_value payment_method  order_frequency  discount_applied  \
# 0    04:51.9      4015.21    Net Banking                9                 5
# 1    39:38.4      2205.61    Credit Card                3                15
# 2    15:18.9       858.84    Net Banking                8                30
# 3    52:58.4       500.00            UPI                1                 0
# 4    17:39.5      1843.50         Wallet                9                40
#
# ...

# %%
# Calculate order frequency per customer
order_frequency = df.groupby('customer_id')['order_id'].count().reset_index()
order_frequency.columns = ['customer_id', 'order_frequency']

# Calculate total revenue per customer (Customer Lifetime Value)
customer_lifetime_value = df.groupby('customer_id')['order_value'].sum().reset_index()
customer_lifetime_value.columns = ['customer_id', 'lifetime_value']

# Merge the two metrics
customer_behavior = pd.merge(order_frequency, customer_lifetime_value, on='customer_id')

# Plot order frequency vs. lifetime value
plt.figure(figsize=(10, 6))
sns.scatterplot(x='order_frequency', y='lifetime_value', data=customer_behavior, alpha=0.6)
plt.title('Customer Behavior: Order Frequency vs. Lifetime Value')
plt.xlabel('Order Frequency')
plt.ylabel('Lifetime Value')
plt.grid(True)
plt.show()

# %%
# Top-performing products by revenue
top_products = df.groupby('product_sku')['order_value'].sum().sort_values(ascending=False).reset_index().head(10)
top_products.columns = ['product_sku', 'total_revenue']

# Plot top-performing products
plt.figure(figsize=(10, 6))
sns.barplot(x='total_revenue', y='product_sku', data=top_products, palette='viridis')
plt.title('Top 10 Performing Products by Revenue')
plt.xlabel('Total Revenue')
plt.ylabel('Product SKU')
plt.show()

# Seasonal trends (monthly revenue)
df['order_date'] = pd.to_datetime(df['order_date'])
df['month'] = df['order_date'].dt.month
monthly_revenue = df.groupby('month')['order_value'].sum().reset_index()

# Plot monthly revenue trends
plt.figure(figsize=(10, 6))
sns.lineplot(x='month', y='order_value', data=monthly_revenue, marker='o')
plt.title('Monthly Revenue Trends')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# Revenue drivers (e.g., by product category)
revenue_by_category = df.groupby('product_category')['order_value'].sum().sort_values(ascending=False).reset_index()

# Plot revenue by product category
plt.figure(figsize=(10, 6))
sns.barplot(x='order_value', y='product_category', data=revenue_by_category, palette='magma')
plt.title('Revenue by Product Category')
plt.xlabel('Total Revenue')
plt.ylabel('Product Category')
plt.show()
# Out:
# <ipython-input-50-54a046894f53>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='total_revenue', y='product_sku', data=top_products, palette='viridis')
# <ipython-input-50-54a046894f53>:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# ...

# %%
# Calculate total conversions per marketing channel
conversions_by_source = df.groupby('source')['order_id'].count().reset_index()
conversions_by_source.columns = ['source', 'conversions']

# Calculate total revenue per marketing channel
revenue_by_source = df.groupby('source')['order_value'].sum().reset_index()
revenue_by_source.columns = ['source', 'total_revenue']

# Merge conversions and revenue
marketing_effectiveness = pd.merge(conversions_by_source, revenue_by_source, on='source')

# Plot marketing effectiveness
plt.figure(figsize=(10, 6))
sns.barplot(x='source', y='total_revenue', data=marketing_effectiveness, palette='plasma')
plt.title('Marketing Effectiveness: Revenue by Source')
plt.xlabel('Marketing Source')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-51-30076978a562>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='source', y='total_revenue', data=marketing_effectiveness, palette='plasma')

# %%
# Calculate return rates by product category and discount
return_rates = df.groupby(['product_category', 'discount_applied'])['return_status'].mean().reset_index()
return_rates.columns = ['product_category', 'discount_applied', 'return_rate']

# Plot return rates by product category
plt.figure(figsize=(12, 6))
sns.barplot(x='product_category', y='return_rate', hue='discount_applied', data=return_rates, palette='coolwarm')
plt.title('Return Rates by Product Category and Discount')
plt.xlabel('Product Category')
plt.ylabel('Return Rate')
plt.xticks(rotation=45)
plt.legend(title='Discount Applied')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
pip install pandas matplotlib seaborn

# %%
# Top-performing products by revenue
top_products = df.groupby('Product')['Revenue'].sum().sort_values(ascending=False).reset_index()
print("Top Performing Products:")
print(top_products.head())

# Seasonal trends (monthly revenue)
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
df['Month'] = df['Purchase Date'].dt.month
monthly_revenue = df.groupby('Month')['Revenue'].sum().reset_index()
print("Monthly Revenue Trends:")
print(monthly_revenue)

# Revenue drivers (e.g., by category)
revenue_by_category = df.groupby('Category')['Revenue'].sum().sort_values(ascending=False).reset_index()
print("Revenue by Category:")
print(revenue_by_category)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-59e6d9eebc3e> in <cell line: 0>()
#       1 # Top-performing products by revenue
# ----> 2 top_products = df.groupby('Product')['Revenue'].sum().sort_values(ascending=False).reset_index()
#       3 print("Top Performing Products:")
#       4 print(top_products.head())
#       5
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Convert 'order_date' to datetime format
df['order_date'] = pd.to_datetime(df['order_date'])

# Aggregate data by day
daily_data = df.groupby(df['order_date'].dt.date).agg({
    'order_value': 'sum',  # Total revenue per day
    'order_id': 'count'    # Total orders per day
}).reset_index()
daily_data.columns = ['order_date', 'daily_revenue', 'daily_orders']

# Plot daily revenue trend
plt.figure(figsize=(12, 6))
sns.lineplot(x='order_date', y='daily_revenue', data=daily_data, label='Daily Revenue', marker='o')
plt.title('Daily Revenue Trend Over Time')
plt.xlabel('Order Date')
plt.ylabel('Daily Revenue')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Plot daily orders trend
plt.figure(figsize=(12, 6))
sns.lineplot(x='order_date', y='daily_orders', data=daily_data, label='Daily Orders', color='orange', marker='o')
plt.title('Daily Orders Trend Over Time')
plt.xlabel('Order Date')
plt.ylabel('Daily Orders')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# Comparison: Daily Revenue vs. Daily Orders (Dual Axis Plot)
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot daily revenue on the primary y-axis
ax1.plot(daily_data['order_date'], daily_data['daily_revenue'], label='Daily Revenue', color='blue', marker='o')
ax1.set_xlabel('Order Date')
ax1.set_ylabel('Daily Revenue', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.grid(True)

# Create a secondary y-axis for daily orders
ax2 = ax1.twinx()
ax2.plot(daily_data['order_date'], daily_data['daily_orders'], label='Daily Orders', color='orange', marker='o')
ax2.set_ylabel('Daily Orders', color='orange')
ax2.tick_params(axis='y', labelcolor='orange')

# Add title and legend
plt.title('Comparison: Daily Revenue vs. Daily Orders')
fig.legend(loc='upper left', bbox_to_anchor=(0.1, 0.9))
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-57-a14067c4b76e>:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# <ipython-input-57-a14067c4b76e> in <cell line: 0>()
#       8
#       9 # Convert 'order_date' to datetime format
# ---> 10 df['order_date'] = pd.to_datetime(df['order_date'])
#      11
#      12 # Aggregate data by day
#
# ...

# %%
print(df['order_date'].unique())
# Out:
# ['04:51.9' '39:38.4' '15:18.9' '52:58.4' '17:39.5' '36:02.2' '33:09.2'
#  '25:13.5' '43:57.8' '28:17.3' '36:45.4' '14:57.3' '01:15.7' '57:17.8'
#  '53:09.2' '28:38.9' '43:14.6' '46:40.0' '14:24.9' '56:02.2' '12:36.8'
#  '35:18.9' '59:27.6' '42:31.4' '08:17.3' '16:23.8' '32:47.6' '47:01.6'
#  '33:30.8' '12:25.9' '36:13.0' '40:43.2' '56:23.8' '58:22.7' '32:36.8'
#  '47:34.1' '11:31.9' '47:55.7' '46:29.2' '51:21.1' '15:40.5' '46:18.4'
#  '31:10.3' '44:51.9' '04:08.6' '26:29.2' '33:20.0' '05:13.5' '38:44.3'
#  '19:49.2' '41:26.5' '14:46.5' '30:16.2' '33:41.6' '21:15.7' '03:57.8'
#  '03:03.8' '16:56.2' '02:31.4' '21:58.9' '55:08.1' '34:46.5' '00:32.4'
#  '05:02.7' '53:52.4' '10:59.5' '16:02.2' '14:14.1' '59:38.4' '11:42.7'
#  '14:03.2' '53:41.6' '51:53.5' '36:34.6' '10:27.0' '41:58.9' '02:53.0'
#  '15:08.1' '30:37.8' '44:19.5' '15:51.4' '00:10.8' '35:40.5' '57:07.0'
#  '50:48.6' '38:11.9' '28:49.7' '03:25.4' '54:14.1' '01:26.5' '08:49.7'
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='%Y-%m-%d')  # Adjust the format as needed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-fb03c47400f1> in <cell line: 0>()
# ----> 1 df['order_date'] = pd.to_datetime(df['order_date'], format='%Y-%m-%d')  # Adjust the format as needed
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065             result = arg.map(cache_array)
#    1066         else:
# -> 1067             values = convert_listlike(arg._values, format)
#    1068             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')
# Out:
# <ipython-input-61-2633a9774d96>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# %%
print(df[df['order_date'].isna()])
# Out:
#     customer_id  customer_tenure customer_location customer_type   order_id  \
# 1     CUST00002               52         Hyderabad     Returning  ORD000002
# 3     CUST00004               15            Jaipur     Returning  ORD000004
# 5     CUST00006                8             Delhi           New  ORD000006
# 6     CUST00007               21             Delhi     Returning  ORD000007
# 7     CUST00008               39             Delhi     Returning  ORD000008
# ..          ...              ...               ...           ...        ...
# 994   CUST00995               13           Kolkata     Returning  ORD000995
# 996   CUST00997                1           Chennai           New  ORD000997
# 997   CUST00998               49             Delhi     Returning  ORD000998
# 998   CUST00999               40            Mumbai     Returning  ORD000999
# 999   CUST01000               32            Jaipur     Returning  ORD001000
#
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'].str.split().str[0], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-6988567f74ca> in <cell line: 0>()
# ----> 1 df['order_date'] = pd.to_datetime(df['order_date'].str.split().str[0], errors='coerce')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'].str.split().str[0], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-6988567f74ca> in <cell line: 0>()
# ----> 1 df['order_date'] = pd.to_datetime(df['order_date'].str.split().str[0], errors='coerce')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'].str.split().str[0], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-6988567f74ca> in <cell line: 0>()
# ----> 1 df['order_date'] = pd.to_datetime(df['order_date'].str.split().str[0], errors='coerce')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Convert 'order_date' to datetime format (with error handling)
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# Check for missing values in 'order_date'
if df['order_date'].isna().any():
    print("Warning: Some dates could not be parsed and were set to NaT.")
    print(df[df['order_date'].isna()])

# Drop rows with invalid dates (optional)
df = df.dropna(subset=['order_date'])

# Aggregate data by day to calculate total sales (order_value) per day
daily_sales = df.groupby(df['order_date'].dt.date)['order_value'].sum().reset_index()
daily_sales.columns = ['order_date', 'total_sales']

# Find the date with the highest sales
max_sales_date = daily_sales.loc[daily_sales['total_sales'].idxmax()]

# Plot the trend of daily sales
plt.figure(figsize=(12, 6))
sns.lineplot(x='order_date', y='total_sales', data=daily_sales, marker='o', color='blue')
plt.title('Trend of Daily Sales Over Time')
plt.xlabel('Order Date')
plt.ylabel('Total Sales (Order Value)')
plt.xticks(rotation=45)
plt.grid(True)

# Highlight the date with the highest sales
plt.axvline(pd.to_datetime(max_sales_date['order_date']), color='red', linestyle='--', label=f'Highest Sales: {max_sales_date["order_date"]} (${max_sales_date["total_sales"]:,.2f})')
plt.legend()
plt.show()

# Print the date with the highest sales
print(f"Date with Highest Sales: {max_sales_date['order_date']} (Total Sales: ${max_sales_date['total_sales']:,.2f})")
# Out:
# <ipython-input-66-01f165a99b11>:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')
# ...
#     customer_id  customer_tenure customer_location customer_type   order_id  \
# 1     CUST00002               52         Hyderabad     Returning  ORD000002
# 3     CUST00004               15            Jaipur     Returning  ORD000004
# 5     CUST00006                8             Delhi           New  ORD000006
# 6     CUST00007               21             Delhi     Returning  ORD000007
# 7     CUST00008               39             Delhi     Returning  ORD000008
# ..          ...              ...               ...           ...        ...
# 994   CUST00995               13           Kolkata     Returning  ORD000995
# 996   CUST00997                1           Chennai           New  ORD000997
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Convert 'order_date' to datetime format (with error handling)
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# Check for missing values in 'order_date'
if df['order_date'].isna().any():
    print("Warning: Some dates could not be parsed and were set to NaT.")
    print(df[df['order_date'].isna()])

# Drop rows with invalid dates (optional)
df = df.dropna(subset=['order_date'])

# Extract month and year from 'order_date'
df['month'] = df['order_date'].dt.month
df['year'] = df['order_date'].dt.year

# Aggregate data by month to calculate total sales (order_value) per month
monthly_sales = df.groupby(['year', 'month'])['order_value'].sum().reset_index()
monthly_sales['month_name'] = pd.to_datetime(monthly_sales['month'], format='%m').dt.month_name()

# Plot seasonal trends (monthly sales)
plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='order_value', hue='year', data=monthly_sales, marker='o', palette='tab10')
plt.title('Seasonal Trends: Monthly Sales Over Time')
plt.xlabel('Month')
plt.ylabel('Total Sales (Order Value)')
plt.xticks(range(1, 13), labels=[pd.to_datetime(m, format='%m').strftime('%b') for m in range(1, 13)])
plt.grid(True)
plt.legend(title='Year')
plt.show()

# Optional: Aggregate data by season (customize based on your definition of seasons)
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'

df['season'] = df['month'].apply(get_season)
seasonal_sales = df.groupby(['year', 'season'])['order_value'].sum().reset_index()

# Plot seasonal trends (by season)
plt.figure(figsize=(12, 6))
sns.barplot(x='season', y='order_value', hue='year', data=seasonal_sales, palette='coolwarm')
plt.title('Seasonal Trends: Sales by Season')
plt.xlabel('Season')
plt.ylabel('Total Sales (Order Value)')
plt.legend(title='Year')
plt.show()
# Out:
# <ipython-input-67-a1975a68b051>:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')
# ...
#     customer_id  customer_tenure customer_location customer_type   order_id  \
# 1     CUST00002               52         Hyderabad     Returning  ORD000002
# 3     CUST00004               15            Jaipur     Returning  ORD000004
# 5     CUST00006                8             Delhi           New  ORD000006
# 6     CUST00007               21             Delhi     Returning  ORD000007
# 7     CUST00008               39             Delhi     Returning  ORD000008
# ..          ...              ...               ...           ...        ...
# 994   CUST00995               13           Kolkata     Returning  ORD000995
# 996   CUST00997                1           Chennai           New  ORD000997
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Convert 'order_date' to datetime format (with error handling)
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# Check for missing values in 'order_date'
if df['order_date'].isna().any():
    print("Warning: Some dates could not be parsed and were set to NaT.")
    print(df[df['order_date'].isna()])

# Drop rows with invalid dates (optional)
df = df.dropna(subset=['order_date'])

# Extract hour from 'order_date'
df['hour'] = df['order_date'].dt.hour

# Categorize hours into time periods
def get_time_period(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

df['time_period'] = df['hour'].apply(get_time_period)

# Aggregate data by time period to calculate total sales (order_value) per time period
time_period_sales = df.groupby(['time_period'])['order_value'].sum().reset_index()

# Plot time-of-day trends
plt.figure(figsize=(10, 6))
sns.barplot(x='time_period', y='order_value', data=time_period_sales, palette='viridis', order=['Morning', 'Afternoon', 'Evening', 'Night'])
plt.title('Sales Trends by Time of Day')
plt.xlabel('Time Period')
plt.ylabel('Total Sales (Order Value)')
plt.show()

# Optional: Plot trends over time (e.g., daily trends by time period)
df['date'] = df['order_date'].dt.date
daily_time_period_sales = df.groupby(['date', 'time_period'])['order_value'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='order_value', hue='time_period', data=daily_time_period_sales, palette='viridis')
plt.title('Daily Sales Trends by Time of Day')
plt.xlabel('Date')
plt.ylabel('Total Sales (Order Value)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title='Time Period')
plt.show()
# Out:
# <ipython-input-68-829a1b1edd24>:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')
# <ipython-input-68-829a1b1edd24>:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='time_period', y='order_value', data=time_period_sales, palette='viridis', order=['Morning', 'Afternoon', 'Evening', 'Night'])
# ...
#     customer_id  customer_tenure customer_location customer_type   order_id  \
# 1     CUST00002               52         Hyderabad     Returning  ORD000002
# 3     CUST00004               15            Jaipur     Returning  ORD000004
# 5     CUST00006                8             Delhi           New  ORD000006
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Excel file
file_path = "SAADAA_assessment_data.xlsx"
df = pd.read_excel(file_path)

# Convert 'order_date' to datetime format
df['order_date'] = pd.to_datetime(df['order_date'])

# Aggregate data by day to calculate total sales (order_value) per day
daily_sales = df.groupby(df['order_date'].dt.date)['order_value'].sum().reset_index()
daily_sales.columns = ['order_date', 'total_sales']

# Find the date with the highest sales
max_sales_date = daily_sales.loc[daily_sales['total_sales'].idxmax()]

# Plot the trend of daily sales
plt.figure(figsize=(12, 6))
sns.lineplot(x='order_date', y='total_sales', data=daily_sales, marker='o', color='blue')
plt.title('Trend of Daily Sales Over Time')
plt.xlabel('Order Date')
plt.ylabel('Total Sales (Order Value)')
plt.xticks(rotation=45)
plt.grid(True)

# Highlight the date with the highest sales
plt.axvline(pd.to_datetime(max_sales_date['order_date']), color='red', linestyle='--', label=f'Highest Sales: {max_sales_date["order_date"]} (${max_sales_date["total_sales"]:,.2f})')
plt.legend()
plt.show()

# Print the date with the highest sales
print(f"Date with Highest Sales: {max_sales_date['order_date']} (Total Sales: ${max_sales_date['total_sales']:,.2f})")
# Out:
# <ipython-input-58-dd4f0d157637>:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# <ipython-input-58-dd4f0d157637> in <cell line: 0>()
#       8
#       9 # Convert 'order_date' to datetime format
# ---> 10 df['order_date'] = pd.to_datetime(df['order_date'])
#      11
#      12 # Aggregate data by day to calculate total sales (order_value) per day
#
# ...

# %%
# Calculate total conversions per marketing channel
conversions_by_channel = df.groupby('Marketing Channel')['Revenue'].count().reset_index()
conversions_by_channel.columns = ['Marketing Channel', 'Conversions']

# Calculate total revenue per marketing channel
revenue_by_channel = df.groupby('Marketing Channel')['Revenue'].sum().reset_index()
revenue_by_channel.columns = ['Marketing Channel', 'Total Revenue']

# Merge conversions and revenue
marketing_effectiveness = pd.merge(conversions_by_channel, revenue_by_channel, on='Marketing Channel')

# Display the results
print("Marketing Effectiveness:")
print(marketing_effectiveness)

# %%
# Assuming there's a 'Return' column indicating if the product was returned (1 for returned, 0 for not returned)
if 'Return' in df.columns:
    return_rates = df.groupby(['Category', 'Discount'])['Return'].mean().reset_index()
    return_rates.columns = ['Category', 'Discount', 'Return Rate']
    print("Return Rates by Category and Discount:")
    print(return_rates)
else:
    print("No 'Return' column found in the dataset.")

# %%
# Calculate total quantity sold per product
product_sales = df.groupby('Product')['Quantity'].sum().reset_index()
product_sales.columns = ['Product', 'Total Quantity Sold']

# Identify products with low stock (assuming there's a 'Stock' column)
if 'Stock' in df.columns:
    product_stock = df.groupby('Product')['Stock'].mean().reset_index()  # Average stock per product
    inventory_risk = pd.merge(product_sales, product_stock, on='Product')
    inventory_risk['Stockout Risk'] = inventory_risk['Total Quantity Sold'] / inventory_risk['Stock']
    print("Products with High Stockout Risk:")
    print(inventory_risk.sort_values(by='Stockout Risk', ascending=False).head())
else:
    print("No 'Stock' column found in the dataset.")

# Predictive model for inventory optimization (simplified example)
from sklearn.linear_model import LinearRegression

# Prepare data for prediction
inventory_data = df.groupby('Product').agg({'Quantity': 'sum', 'Stock': 'mean'}).reset_index()
inventory_data.columns = ['Product', 'Total Quantity Sold', 'Average Stock']

# Fit a linear regression model
X = inventory_data[['Total Quantity Sold']]
y = inventory_data['Average Stock']
model = LinearRegression()
model.fit(X, y)

# Predict optimal stock levels
inventory_data['Predicted Stock'] = model.predict(X)
print("Predicted Optimal Stock Levels:")
print(inventory_data[['Product', 'Total Quantity Sold', 'Average Stock', 'Predicted Stock']])
